# %% [markdown]
# # Finding Patterns and Anomalies in Everyday Activities at Home
# ### (sample case duration: one day)
# #### Data set: CASAS, Washington State University

# %% [markdown]
# ### Maryam Arabshahi
# ### arabshahi.ma@gmail.com

# %%
from PIL import Image
Image.open('Schlafzimmer_Bewegung.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1000x650 at 0x7F92D5F5C130>

# %%
Image.open('Schlafzimmer_Licht.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1000x650 at 0x7F92D4969A60>

# %%
Image.open('Badezimmer_Bewegung.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1000x650 at 0x7F92D4969AF0>

# %%
Image.open('Badezimmer_Licht.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1000x650 at 0x7F92D67C04C0>

# %%
Image.open('Küche_Bewegung.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1000x650 at 0x7F92D4969610>

# %%
Image.open('Küche_Licht.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1000x650 at 0x7F92D4969F70>

# %%
Image.open('Wohnzimmer_Bewegung.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1000x650 at 0x7F92E4067B20>

# %%
Image.open('Wohnzimmer_Licht.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1000x650 at 0x7F92D4969D60>
